# %% [markdown]
# # [作業目標]
# - 對資料做更多處理 : 顯示特定欄位的統計值與直方圖

# %% [markdown]
# # [作業重點]
# - 試著顯示特定欄位的基礎統計數值 (In[4], Out[4], Hint : describe())
# - 試著顯示特定欄位的直方圖 (In[5], Out[5], Hint : .hist())

# %%
# Import 需要的套件
import os
import numpy as np
import pandas as pd

# 設定 data_path
dir_data = 'C:/Users/rich chang/Documents/GitHub/3rd-ML100Days/data/'

# %%
f_app_train = os.path.join(dir_data, 'application_train.csv')
app_train = pd.read_csv(f_app_train)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 練習時間

# %% [markdown]
# 觀察有興趣的欄位的資料分佈，並嘗試找出有趣的訊息
# #### Eg
# - 計算任意欄位的平均數及標準差
# - 畫出任意欄位的[直方圖](https://zh.wikipedia.org/zh-tw/%E7%9B%B4%E6%96%B9%E5%9B%BE)
#
# ### Hints:
# - [Descriptive Statistics For pandas Dataframe](https://chrisalbon.com/python/data_wrangling/pandas_dataframe_descriptive_stats/)
# - [pandas 中的繪圖函數](https://amaozhao.gitbooks.io/pandas-notebook/content/pandas%E4%B8%AD%E7%9A%84%E7%BB%98%E5%9B%BE%E5%87%BD%E6%95%B0.html)

# %%
# https://chrisalbon.com/python/data_wrangling/pandas_dataframe_descriptive_stats/

# app_train['AMT_GOODS_PRICE'].cumsum()
# app_train['DAYS_BIRTH'].std()
# app_train['ELEVATORS_MODE'].skew()  # skewness 歪斜度
# app_train['APARTMENTS_MODE'].var()
# app_train['LIVINGAPARTMENTS_MODE'].kurt()# kurtosis 峭度、峰態
# app_train['FLAG_DOCUMENT_3'].corr()
# app_train[''].corr()  # correlation Matrix Of Values
# app_train[''].cov()  # Covariance Matrix Of Values
app_train['REGION_POPULATION_RELATIVE'].describe()
# Out:
# count    307511.000000
# mean          0.020868
# std           0.013831
# min           0.000290
# 25%           0.010006
# 50%           0.018850
# 75%           0.028663
# max           0.072508
# Name: REGION_POPULATION_RELATIVE, dtype: float64

# %%
# https://amaozhao.gitbooks.io/pandas-notebook/content/pandas%E4%B8%AD%E7%9A%84%E7%BB%98%E5%9B%BE%E5%87%BD%E6%95%B0.html

s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0), columns=['A', 'B', 'C', 'D'], index=np.arange(0, 100, 10))
df.plot()

# %%
# 加上 kind='bar'或 kind='barh' 即可生成柱状图

fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.randn(16), index=list('abcdefghijklmnop'))
data.plot(kind='bar', ax=axes[0], color='k', alpha=0.7)
data.plot(kind='barh', ax=axes[1], color='k', alpha=0.7)  # 如下图1(Series)

# %%
df = pd.DataFrame(np.random.rand(6, 4), index=['one', 'two', 'three', 'four', 'five', 'six'], columns=pd.Index(['A', 'B', 'C', 'D'], name="Genus"))
df.plot(kind='bar')  # 如下图2(DF)

# %%
# 
# total = pd.crosstab(app_train.day, tips.size)

# %%
# histogram
# app_train[''] = tips[''] / tips['']
# app_train[''].hist(bins=50)

# %%
# KDE diagram
# app_train['tip_pct'].plot(kind='kde')    # 如下图1
# comp1 = np.random.normal(0, 1, size=200)
# comp2 = np.random.normal(10, 2, size=200)
# values = Series(np.concatenate([comp1, comp2]))
# values.hist(bins=100, alpha=0.3, color='k', normed=True)
# values.plot(kind='kde', style='k--')    # 如图2

# %%
# Scatter Plot

'''
macro = pd.read_csv('ch08/macrodata.csv')
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
trans_data = np.log(data).diff().dropna()
plt.scatter(trans_data['m1'], trans_data['unemp'])
plt.title('Changes in log %s vs. log %s' % ('m1', 'unemp'))    # 见下图1

from pandas.tools.plotting import scatter_matrix
scatter_matrix(trans_data, alpha=0.2, figsize=(6, 6), diagonal='kde')
'''
# Out:
# "\nmacro = pd.read_csv('ch08/macrodata.csv')\ndata = macro[['cpi', 'm1', 'tbilrate', 'unemp']]\ntrans_data = np.log(data).diff().dropna()\nplt.scatter(trans_data['m1'], trans_data['unemp'])\nplt.title('Changes in log %s vs. log %s' % ('m1', 'unemp'))    # 见下图1\n\nfrom pandas.tools.plotting import scatter_matrix\nscatter_matrix(trans_data, alpha=0.2, figsize=(6, 6), diagonal='kde')\n"
